# %%
import pandas as pd
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import classification_report

# Load preprocessed data
data = pd.read_csv('D:\\Important\\Projects\\IOT_23\\iot23_Preprocessed.csv')

# Select features for LOF (e.g., numeric features)
X = data.drop(['label' , 'encoded_label'], axis=1)

# Creating a Object for Local Outlier Factor model
lof=LocalOutlierFactor(n_neighbors=20,contamination=0.4)

# Get the predictions
data['lof_labels'] = lof.fit_predict(X)

# The model outputs 1 for inliers and -1 for outliers (anomalies).

# Generate and print the classification report
print("\n--- Local Outlier Factor Classification Report ---")
print(classification_report(data['encoded_label'], data['lof_labels'],
                            target_names=["Malicious", "Benign"]))
# Out:
# --- Local Outlier Factor Classification Report ---
#               precision    recall  f1-score   support
#
#    Malicious       0.78      0.35      0.48   1246865
#       Benign       0.09      0.39      0.14    197809
#
#     accuracy                           0.35   1444674
#    macro avg       0.44      0.37      0.31   1444674
# weighted avg       0.69      0.35      0.44   1444674
