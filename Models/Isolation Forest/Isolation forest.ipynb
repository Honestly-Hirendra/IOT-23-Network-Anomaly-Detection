# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report

# Load preprocessed data
data = pd.read_csv('D:\Important\Projects\IOT_23\iot23_Preprocessed.csv')

# Select features for IsolationForest (e.g., numeric features)
X = data.drop(['label' , 'encoded_label'], axis=1)

iso_forest = IsolationForest(contamination=0.5, random_state=42)
data['iso_forest_labels'] = iso_forest.fit_predict(X)
print(data['iso_forest_labels'] )

# The model outputs 1 for inliers and -1 for outliers (anomalies).

print("--- Isolation Forest Classification Report ---")
print(classification_report(data['encoded_label'], data['iso_forest_labels'],
                            target_names=["Malicious", "Benign"]))
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\I'
# <>:6: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\hiren\AppData\Local\Temp\ipykernel_20932\2886472134.py:6: SyntaxWarning: invalid escape sequence '\I'
#   data = pd.read_csv('D:\Important\Projects\IOT_23\iot23_Preprocessed.csv')
# 0         -1
# 1         -1
# 2         -1
# 3         -1
# 4         -1
#           ..
# 1444669   -1
# 1444670   -1
# 1444671   -1
# 1444672   -1
# 1444673   -1
# Name: iso_forest_labels, Length: 1444674, dtype: int64
# --- Isolation Forest Classification Report ---
#               precision    recall  f1-score   support
#
#    Malicious       0.80      0.46      0.58   1246865
#       Benign       0.07      0.26      0.11    197809
#
#     accuracy                           0.43   1444674
#    macro avg       0.43      0.36      0.35   1444674
# weighted avg       0.70      0.43      0.52   1444674
